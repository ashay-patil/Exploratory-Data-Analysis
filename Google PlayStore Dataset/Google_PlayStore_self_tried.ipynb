# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ## Insights and Observation
#
# The dataset has missing value

# %% [markdown]
# # Handling Reviews

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
## Checking whether all the values in the Reviews column numeric or is there any character present in the values.


mask = pd.to_numeric(df['Reviews'], errors='coerce').isna() & df['Reviews'].notna()
df[mask]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## Convert the 3.0M to 3,00,000

def convert_units(x):
    if pd.isna(x):
        return x

    x = str(x).strip()

    if x.endswith('M'):
        return float(x[:-1]) * 1_000_000
    if x.endswith('K'):
        return float(x[:-1]) * 1_000
    if x.endswith('B'):
        return float(x[:-1]) * 1_000_000_000

    return float(x)

## This will also convert my column to float
df['Reviews'] = df['Reviews'].apply(convert_units)

mask = pd.to_numeric(df['Reviews'], errors='coerce').isna() & df['Reviews'].notna()
df[mask]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
## Now there is no non-numeric entry in Reviews 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Handling Size

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 54k                      1
# 562k                     1
# 847k                     1
# 404k                     1
# 34k                      1
# Name: count, Length: 462, dtype: int64

# %%
## Checking which entries are not matching my expected pattern 

mask = ~df['Size'].str.match(r'^\d+(\.\d+)?[Mk]$', na=False)
df.loc[mask, 'Size'].unique()
# Out:
# array(['Varies with device', '1,000+'], dtype=object)

# %%
## Cleaning the garbage values

df['Size'] = df['Size'].replace('Varies with device', pd.NA)

df['Size'] = (
    df['Size']
    .str.replace(',', '', regex=False)
    .str.replace('+', '', regex=False)
)

df['Size']
# Out:
# 0         19M
# 1         14M
# 2        8.7M
# 3         25M
# 4        2.8M
#          ...
# 10836     53M
# 10837    3.6M
# 10838    9.5M
# 10839    <NA>
# 10840     19M
# Name: Size, Length: 10841, dtype: object

# %%
df['Size'] = (
    df['Size']
    .str.replace('M', 'e6', regex=False)
    .str.replace('k', 'e3', regex=False)
)

# %%
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# %%
df['Size'].unique()
# Out:
# array([1.90e+07, 1.40e+07, 8.70e+06, 2.50e+07, 2.80e+06, 5.60e+06,
#        2.90e+07, 3.30e+07, 3.10e+06, 2.80e+07, 1.20e+07, 2.00e+07,
#        2.10e+07, 3.70e+07, 2.70e+06, 5.50e+06, 1.70e+07, 3.90e+07,
#        3.10e+07, 4.20e+06, 7.00e+06, 2.30e+07, 6.00e+06, 6.10e+06,
#        4.60e+06, 9.20e+06, 5.20e+06, 1.10e+07, 2.40e+07,      nan,
#        9.40e+06, 1.50e+07, 1.00e+07, 1.20e+06, 2.60e+07, 8.00e+06,
#        7.90e+06, 5.60e+07, 5.70e+07, 3.50e+07, 5.40e+07, 2.01e+05,
#        3.60e+06, 5.70e+06, 8.60e+06, 2.40e+06, 2.70e+07, 2.50e+06,
#        1.60e+07, 3.40e+06, 8.90e+06, 3.90e+06, 2.90e+06, 3.80e+07,
#        3.20e+07, 5.40e+06, 1.80e+07, 1.10e+06, 2.20e+06, 4.50e+06,
#        9.80e+06, 5.20e+07, 9.00e+06, 6.70e+06, 3.00e+07, 2.60e+06,
#        7.10e+06, 3.70e+06, 2.20e+07, 7.40e+06, 6.40e+06, 3.20e+06,
#        8.20e+06, 9.90e+06, 4.90e+06, 9.50e+06, 5.00e+06, 5.90e+06,
#        1.30e+07, 7.30e+07, 6.80e+06, 3.50e+06, 4.00e+06, 2.30e+06,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
sns.histplot(df['Size'])
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %%
median_size = df['Size'].median()
df['Size'] = df['Size'].fillna(median_size)

df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # Handling Rating

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size     Installs  Type Price Content Rating  \
# 0     159.0  19000000.0      10,000+  Free     0       Everyone
# 1     967.0  14000000.0     500,000+  Free     0       Everyone
# 2   87510.0   8700000.0   5,000,000+  Free     0       Everyone
# 3  215644.0  25000000.0  50,000,000+  Free     0           Teen
# 4     967.0   2800000.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(1474)

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # Handling Installs

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size     Installs  Type Price Content Rating  \
# 0     159.0  19000000.0      10,000+  Free     0       Everyone
# 1     967.0  14000000.0     500,000+  Free     0       Everyone
# 2   87510.0   8700000.0   5,000,000+  Free     0       Everyone
# 3  215644.0  25000000.0  50,000,000+  Free     0           Teen
# 4     967.0   2800000.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
## Cleaning the unexpected garbage  
df['Installs'] = df['Installs'].replace('Free', '0')

df['Installs'] = (
    df['Installs']
    .str.replace(',', '', regex=False)
    .str.replace('+', '', regex=False)
)

df['Installs'] = df['Installs'].astype(float)

# %%
df['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %%
df['Installs'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size    Installs  Type Price Content Rating  \
# 0     159.0  19000000.0     10000.0  Free     0       Everyone
# 1     967.0  14000000.0    500000.0  Free     0       Everyone
# 2   87510.0   8700000.0   5000000.0  Free     0       Everyone
# 3  215644.0  25000000.0  50000000.0  Free     0           Teen
# 4     967.0   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# # Handling Price

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
## Checking the unexpected values 

valid_price_pattern = r'^0$|^\$\d+(\.\d{1,2})?$'

weird_prices = df.loc[
    ~df['Price'].str.match(valid_price_pattern, na=False),
    'Price'
].unique()

weird_prices
# Out:
# array(['Everyone'], dtype=object)

# %%
df['Price'] = df['Price'].replace('Everyone', pd.NA)

# %%
df[df['Price'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size  Installs Type Price Content Rating             Genres  \
# 10472  1000.0       0.0    0  <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Price'] = (
    df['Price']
    .str.replace('$', '', regex=False)
)

# %%
df[df['Price'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size  Installs Type Price Content Rating             Genres  \
# 10472  1000.0       0.0    0  <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26', <NA>,
#        '1.20', '1.04'], dtype=object)

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
df[df['Price'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1000.0       0.0    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
df['Price'].value_counts()
# Out:
# Price
# 0.00      10040
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 3.61          1
# 394.99        1
# 1.26          1
# 1.20          1
# 1.04          1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'] = df['Price'].fillna(0.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size    Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000.0  Free    0.0       Everyone
# 1     967.0  14000000.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8700000.0   5000000.0  Free    0.0       Everyone
# 3  215644.0  25000000.0  50000000.0  Free    0.0           Teen
# 4     967.0   2800000.0    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# # Handling Current Ver

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       shape=(2833,), dtype=object)

# %%
## Checking the unexpected values 

valid_version_pattern = r'^\d+(\.\d+)+$'

weird_version = df.loc[
    ~df['Current Ver'].str.match(valid_version_pattern, na=False),
    'Current Ver'
].unique()

weird_version
# Out:
# array(['Varies with device', nan, '1', '2.20 Build 02', '18.05.31+530',
#        '3.0.1.11 (Build 311)', '3.4.3_world', 'R6.0.3',
#        '1.60.0.31354-release', '37.1.206017801.DR37_RC14', '7.3(800241)',
#        '196', '8.1.2-6310', '5.1.2-6310', '4.4B', '1.308.us', '3.8.75a',
#        '4.9.2 (Oasis)', '1.', '2', '1.5-beta', '10', '3.6.0.115_FN',
#        '1.5-play', '1.1.1-play', 'v1.8b22p13', '2.3.34 Prod', '43',
#        'Cannonau 3.11.11', '8.0bld14', '4.1.1-0-prod', '3.04 - Beta',
#        '3.2.0d', '2.76.2.0-android', 'p5.7.1', '7.3.4-play', '37',
#        '3.3.0(1)', 'Public.Heal', '1.31.0-15160.950adac99', '8.2.0_8',
#        '858', 'v3.1.1', '5.2.4(881)', '1.0.0.21_180410', '2.4.12-r244',
#        'Version:6.97', '5.2.2018010801-1', '3.8.5.Go', '3196', '5423',
#        '2.0081_206', '1_39_93', '108', '8', '60', '1.2.3-play', '149',
#        '3.2.0h', '37893', '20180609', '7', '1.10.0.user.pro.release',
#        '4.1.5 (Steglitz)', '1.7.1 (946)', '3.1-2018 – (13)',
# ...

# %%
## Exctracting the numeric dotted parts of weird versions 

df['Current Ver'] = (
    df['Current Ver']
    .str.extract(r'(\d+(?:\.\d+)+)')
)

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       shape=(2536,), dtype=object)

# %%
## Checking again whether the unexpected values are there or not

valid_version_pattern = r'^\d+(\.\d+)+$'

weird_version = df.loc[
    ~df['Current Ver'].str.match(valid_version_pattern, na=False),
    'Current Ver'
].unique()

weird_version
# Out:
# array([nan], dtype=object)

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                                   App             Category  \
# 3                               Sketch - Draw & Paint       ART_AND_DESIGN
# 15                    Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 37                                 Floor Plan Creator       ART_AND_DESIGN
# 39      How To Color Disney Princess - Coloring Pages       ART_AND_DESIGN
# 42                         Textgram - write on photos       ART_AND_DESIGN
# ...                                               ...                  ...
# 10780  Modern Counter 3: FPS Multiplayers battlegro 3               FAMILY
# 10822                                       PLMGSS FR         PRODUCTIVITY
# 10826       Frim: get new friends on local chat rooms               SOCIAL
# 10839                   The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840   iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## We cant filter the version column more... The entries are immensly different and there is not fixed pattern

# %% [markdown]
# ## Ordinal Encoding is the only way

# %% [markdown]
# # Handling Last Updated

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       shape=(1378,), dtype=object)

# %%
## Finding weird dates 

date_pattern = r'^(January|February|March|April|May|June|July|August|September|October|November|December)\s\d{1,2},\s\d{4}$'

weird_dates = df.loc[
    ~df['Last Updated'].str.match(date_pattern, na=False),
    'Last Updated'
].unique()

weird_dates
# Out:
# array(['1.0.19'], dtype=object)

# %%
df['Last Updated'] = pd.to_datetime(
    df['Last Updated'],
    format='%B %d, %Y',
    errors='coerce'
)

# %%
df[df['Last Updated'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1000.0       0.0    0    0.0            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT         4.0         NaN

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size    Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000.0  Free    0.0       Everyone
# 1     967.0  14000000.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8700000.0   5000000.0  Free    0.0       Everyone
# 3  215644.0  25000000.0  50000000.0  Free    0.0           Teen
# 4     967.0   2800000.0    100000.0  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# ...

# %%
newdf = pd.read_csv('googleplaystore.csv')
newdf.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
newdf['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
newdf['Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
newdf['Price'] = newdf['Price'].replace('Everyone', None)

# %%
newdf['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
newdf['Price'].isnull().sum()
# Out:
# np.int64(1)

# %%
newdf[newdf['Price'].isnull()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type Price Content Rating             Genres  \
# 10472  1,000+     Free    0  None            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df2 = newdf[newdf['Price'].isnull()]['Price'].astype(float)

# %%
df2
# Out:
# 10472   NaN
# Name: Price, dtype: float64
